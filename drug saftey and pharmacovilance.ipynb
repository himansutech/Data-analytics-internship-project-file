# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\himan\Desktop\project\Drug safety and pharmacovigilance.csv')

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
df.tail()
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
df[['Age','BP']]
# Out:
#      Age      BP
# 0     23    HIGH
# 1     47     LOW
# 2     47     LOW
# 3     28  NORMAL
# 4     61     LOW
# ..   ...     ...
# 195   56     LOW
# 196   16     LOW
# 197   52  NORMAL
# 198   23  NORMAL
# 199   40     LOW
#
# [200 rows x 2 columns]

# %%
df['Age']>40
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 195     True
# 196    False
# 197     True
# 198    False
# 199    False
# Name: Age, Length: 200, dtype: bool

# %%
df[df['Age']>40]
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 4     61   F     LOW        HIGH   18.043  DrugY
# 6     49   F  NORMAL        HIGH   16.275  DrugY
# 7     41   M     LOW        HIGH   11.037  drugC
# ..   ...  ..     ...         ...      ...    ...
# 192   72   M     LOW        HIGH   16.310  DrugY
# 193   72   M     LOW        HIGH    6.769  drugC
# 194   46   F    HIGH        HIGH   34.686  DrugY
# 195   56   F     LOW        HIGH   11.567  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
#
# [113 rows x 6 columns]

# %%
df[(df['Age']>40)&(df['BP']=='HIGH')]
# Out:
#      Age Sex    BP Cholesterol  Na_to_K   Drug
# 17    43   M  HIGH        HIGH   13.972  drugA
# 31    74   M  HIGH        HIGH    9.567  drugB
# 33    65   F  HIGH      NORMAL   31.876  DrugY
# 41    58   F  HIGH      NORMAL   14.239  drugB
# 50    58   F  HIGH        HIGH   19.416  DrugY
# 54    68   F  HIGH      NORMAL   10.189  drugB
# 56    65   M  HIGH      NORMAL   11.340  drugB
# 64    60   F  HIGH        HIGH   13.303  drugB
# 70    70   M  HIGH        HIGH   13.967  drugB
# 80    60   M  HIGH        HIGH   13.934  drugB
# 85    59   M  HIGH        HIGH   13.935  drugB
# 91    41   M  HIGH      NORMAL   15.156  DrugY
# 97    56   F  HIGH        HIGH   25.395  DrugY
# 101   45   F  HIGH        HIGH   12.854  drugA
# 108   72   M  HIGH      NORMAL    9.677  drugB
# 110   50   M  HIGH        HIGH    7.490  drugA
# 115   51   M  HIGH        HIGH   18.295  DrugY
# 119   61   F  HIGH        HIGH   25.475  DrugY
# 124   53   F  HIGH      NORMAL   12.495  drugB
# ...

# %%
df.groupby('BP').count()
# Out:
#         Age  Sex  Cholesterol  Na_to_K  Drug
# BP
# HIGH     77   77           77       77    77
# LOW      64   64           64       64    64
# NORMAL   59   59           59       59    59

# %%
df.shape
# Out:
# (200, 6)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
df.dtypes
# Out:
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %%
df.groupby(['Age','Drug']).count()
# Out:
#            Sex  BP  Cholesterol  Na_to_K
# Age Drug
# 15  DrugY    2   2            2        2
#     drugX    1   1            1        1
# 16  DrugY    2   2            2        2
#     drugC    1   1            1        1
# 17  drugX    1   1            1        1
# ...        ...  ..          ...      ...
# 72  drugX    1   1            1        1
# 73  DrugY    2   2            2        2
# 74  DrugY    2   2            2        2
#     drugB    1   1            1        1
#     drugX    1   1            1        1
#
# [135 rows x 4 columns]

# %%
df.groupby('Age').agg({'Na_to_K':'mean','Cholesterol':'max'})
# Out:
#        Na_to_K Cholesterol
# Age
# 15   14.338333      NORMAL
# 16   15.509667      NORMAL
# 17   10.832000      NORMAL
# 18   23.404667      NORMAL
# 19   19.641000      NORMAL
# 20   16.967000      NORMAL
# 21   28.632000      NORMAL
# 22   15.964600      NORMAL
# 23   16.497143      NORMAL
# 24   16.080750      NORMAL
# 25   19.011000        HIGH
# 26   16.634250      NORMAL
# 28   17.021143      NORMAL
# 29   21.153000        HIGH
# 30   10.443000        HIGH
# 31   17.633250      NORMAL
# 32   12.290000      NORMAL
# 33   33.486000        HIGH
# 34   18.320250      NORMAL
# 35    9.969667      NORMAL
# 36   13.716250      NORMAL
# 37   14.776000      NORMAL
# 38   19.832000      NORMAL
# 39   14.867000      NORMAL
# 40   16.426000      NORMAL
# 41   16.959250      NORMAL
# 42   20.771500      NORMAL
# 43   15.393750      NORMAL
# 45   12.298000      NORMAL
# 46   20.985500      NORMAL
# 47   15.779625      NORMAL
# 48   12.741000      NORMAL
# 49   10.824857      NORMAL
# ...

# %%
df.isna().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
df=df.dropna()

# %%
df=df.fillna(369)

# %%
df=df.rename(columns={'Na_to_K':'Sodium to Potassium Ratio'})

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Sodium to Potassium Ratio   Drug
# 0   23   F    HIGH        HIGH                     25.355  DrugY
# 1   47   M     LOW        HIGH                     13.093  drugC
# 2   47   M     LOW        HIGH                     10.114  drugC
# 3   28   F  NORMAL        HIGH                      7.798  drugX
# 4   61   F     LOW        HIGH                     18.043  DrugY

# %%
df['Age2']=df['Age'].apply(lambda x : x * 1)

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Sodium to Potassium Ratio   Drug  Age2
# 0   23   F    HIGH        HIGH                     25.355  DrugY    23
# 1   47   M     LOW        HIGH                     13.093  drugC    47
# 2   47   M     LOW        HIGH                     10.114  drugC    47
# 3   28   F  NORMAL        HIGH                      7.798  drugX    28
# 4   61   F     LOW        HIGH                     18.043  DrugY    61

# %%
df['Drug'].unique
# Out:
# <bound method Series.unique of 0      DrugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      DrugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object>

# %%
df=df.drop(columns=['Age2'])

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Sodium to Potassium Ratio   Drug
# 0   23   F    HIGH        HIGH                     25.355  DrugY
# 1   47   M     LOW        HIGH                     13.093  drugC
# 2   47   M     LOW        HIGH                     10.114  drugC
# 3   28   F  NORMAL        HIGH                      7.798  drugX
# 4   61   F     LOW        HIGH                     18.043  DrugY

# %%
newdf=df[['Sex','Drug']]
newdf
# Out:
#     Sex   Drug
# 0     F  DrugY
# 1     M  drugC
# 2     M  drugC
# 3     F  drugX
# 4     F  DrugY
# ..   ..    ...
# 195   F  drugC
# 196   M  drugC
# 197   M  drugX
# 198   M  drugX
# 199   F  drugX
#
# [200 rows x 2 columns]

# %%
df.iloc[5]
# Out:
# Age                              22
# Sex                               F
# BP                           NORMAL
# Cholesterol                    HIGH
# Sodium to Potassium Ratio     8.607
# Drug                          drugX
# Name: 5, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.iloc[5])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:20]
# Out:
#     Age Sex      BP Cholesterol  Sodium to Potassium Ratio   Drug
# 0    23   F    HIGH        HIGH                     25.355  DrugY
# 1    47   M     LOW        HIGH                     13.093  drugC
# 2    47   M     LOW        HIGH                     10.114  drugC
# 3    28   F  NORMAL        HIGH                      7.798  drugX
# 4    61   F     LOW        HIGH                     18.043  DrugY
# 5    22   F  NORMAL        HIGH                      8.607  drugX
# 6    49   F  NORMAL        HIGH                     16.275  DrugY
# 7    41   M     LOW        HIGH                     11.037  drugC
# 8    60   M  NORMAL        HIGH                     15.171  DrugY
# 9    43   M     LOW      NORMAL                     19.368  DrugY
# 10   47   F     LOW        HIGH                     11.767  drugC
# 11   34   F    HIGH      NORMAL                     19.199  DrugY
# 12   43   M     LOW        HIGH                     15.376  DrugY
# ...

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, Age                              23
# Sex                               F
# BP                             HIGH
# Cholesterol                    HIGH
# Sodium to Potassium Ratio    25.355
# Drug                          DrugY
# Name: 0, dtype: object)
# (1, Age                              47
# Sex                               M
# BP                              LOW
# Cholesterol                    HIGH
# Sodium to Potassium Ratio    13.093
# Drug                          drugC
# Name: 1, dtype: object)
# (2, Age                              47
# Sex                               M
# BP                              LOW
# Cholesterol                    HIGH
# Sodium to Potassium Ratio    10.114
# Drug                          drugC
# Name: 2, dtype: object)
# (3, Age                              28
# Sex                               F
# BP                           NORMAL
# Cholesterol                    HIGH
# Sodium to Potassium Ratio     7.798
# ...
